# %% [markdown]
# **Instruction**: Import the pandas library with the standard alias **pd.**

# %% [markdown]
# **Run** the following code:
#
# !pip install pandas
#
# import pandas as pd

# %% [markdown]
# **Instruction:** Read the "TechFlow.csv" file into a DataFrame named **df.**

# %% [markdown]
# **Run** The following code:
#
# df = pd.read_csv('/path/TechFlow.csv')

# %% [markdown]
# **Instruction:** Display the first 5 rows of the DataFrame to inspect the data.
#
# **Run** the following code
#
#
# df.head()
